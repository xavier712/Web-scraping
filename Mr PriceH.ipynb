# %%
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import datetime
from datetime import datetime
import time
import pandas as pd

Product_name=[]
Product_price=[]
Product_price_disc=[]
Product_price_final=[]




##############################################################################################################

Links=['https://www.mrphome.com/en_za/shop/furniture/shop-living-room/couches-sofas']
#Getting links:
for link in Links:
    path = 'C:/Users/XavierM/Desktop/chromedriver.exe'
    driver = webdriver.Chrome(executable_path=path)
    web=f'{link}'
    driver.get(web)
    
# =============================================================================
   
    time.sleep(2)
#                 container =driver.find_element(By.XPATH, './/ion-grid[@class="product-grid md hydrated"]')
    container=driver.find_element(By.XPATH, './/ion-col[@class="product listing-page size-6 size-3-md size-3-lg md hydrated"]')
#                 container = driver.find_element(By.CLASS_NAME,'product-grid md hydrated')
    products= container.find_elements(By.XPATH, './/ion-list[@class="product-info md list-md hydrated"]')
    #products = driver.find_elements(by=By.CSS_SELECTOR,value="ion-col.product:nth-child(1) > ion-list:nth-child(2)")


    for product in products:
        
        try:
            Product_name.append(product.find_element(By.XPATH, './/ion-text[contains(@class,"md hydrated")]').text)
            Product_price=(driver.find_element(By.XPATH, './/ion-label[@class,"price h3 regular-price sc-ion-label-md-h sc-ion-label-md-s md hydrated"]').text)
        except:
            break




                    #Product_price.append(product.find_element(by=By.CSS_SELECTOR,value="#main-content > div.product-listing > ion-grid.product-grid.md.hydrated > ion-row > ion-col:nth-child(5) > ion-list > ion-label"))
                    #Category = driver.find_element(by=By.CSS_SELECTOR,value=''

                    #href.append(product.find_element(By.XPATH,'.//a').get_attribute('href'))






    #                     


    

    driver.quit()    

    df_okFURN4=pd.DataFrame({'Product_name':Product_name,'Product_price':Product_price })
    df_okFURN4.to_csv('C:/Users/XavierM/Downloads/MRPre809fg8j0ffj8jj55jgj95ggh08f98hdnhngh44675988000080880490000¾859999uhgfu955855.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22512/1856252030.py in <module>
#      69     driver.quit()
#      70
# ---> 71     df_okFURN4=pd.DataFrame({'Product_name':Product_name,'Product_price':Product_price })
#      72     df_okFURN4.to_csv('C:/Users/XavierM/Downloads/MRPre809fg8j0ffj8jj55jgj95ggh08f98hdnhngh44675988000080880490000¾859999uhgfu955855.csv', index=False)
#
# ~\D\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ...

# %%
print(products)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="26adef7edc6c34765a1f41d21d137458", element="08129acd-9dc0-490d-85f2-f68b7173bbd5")>]

# %%
print(Product_name)

# %%
print(Product_name)
# Out:
# ['Studio Sleeper Couch', 'Pillow Top 3 Seater Sofa']

# %%
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import datetime
from datetime import datetime
import time
import pandas as pd




##############################################################################################################

#Getting links:
Links=[]
path = 'C:/Users/XavierM/Documents/chromedriver.exe'
driver = webdriver.Chrome(executable_path=path)
web='https://www.mrphome.com/home'
driver.get(web)


container = driver.find_element(By.XPATH,'.//div[@class="app store store-mrphome store-mrphome-en store-mrphome-en-za"]')
products= container.find_elements(By.XPATH,'.//div[@class="subs-level"]/a')

for product in products:
        Links.append(product.get_attribute('href'))
       
driver.quit()
Selected_links=Links[12:30]
for (i, item) in enumerate(Links, start=0):
    print(i, item)
    
driver.quit() 


        
######################################################################################################################

#Select links                                                        
#Selected_links=Links[0:3]
# Out:
# 0 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/colab-2021
# 1 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/stripe-bed-and-bath-2022
# 2 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/scent-sational-1
# 3 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/clocks-frames-shelves-2022
# 4 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/all-the-holiday-feels
# 5 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/coast-outdoor-dps
# 6 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/happiness-lives-here
# 7 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/sofa-so-good
# 8 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/same-wavelength
# 9 https://www.mrphome.com/en_za/shop/inspiration/get-the-look/staycation-state-of-mind
# 10 https://www.mrphome.com/en_za/shop/inspiration/highlights/homeware-top-sellers
# ...
